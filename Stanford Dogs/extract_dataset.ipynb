# %%
import os
import shutil
import numpy as np
import random

# Set random seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)

def split_caltech_dogs_dataset(
    dataset_path='./dataset',
    output_path='./dogs_split',
    train_ratio=0.7,
    val_ratio=0.15
):
    """
    Split Caltech Dogs dataset with breed subfolders into train/val/test sets.
    
    Args:
        dataset_path: Path to dataset with images/ and annotation/ folders
        output_path: Where to save the split dataset
        train_ratio: Proportion for training (default: 0.7)
        val_ratio: Proportion for validation (default: 0.15)
    Returns:
        Path to the organized dataset
    """
    
    # Define paths
    images_dir = os.path.join(dataset_path, 'images')
    annotation_dir = os.path.join(dataset_path, 'annotation')
    
    # Check if directories exist
    if not os.path.exists(images_dir):
        raise FileNotFoundError(f"Images directory not found: {images_dir}")
    if not os.path.exists(annotation_dir):
        print(f"Warning: Annotation directory not found: {annotation_dir}")
    
    # Create output directory structure
    splits = ['train', 'val', 'test']
    for split in splits:
        os.makedirs(os.path.join(output_path, split, 'images'), exist_ok=True)
        os.makedirs(os.path.join(output_path, split, 'annotation'), exist_ok=True)
    
    # Get all breed folders
    breed_folders = sorted([d for d in os.listdir(images_dir) 
                           if os.path.isdir(os.path.join(images_dir, d))])
    
    print(f"Found {len(breed_folders)} breed folders")
    print("-" * 50)
    
    # Statistics
    total_train = 0
    total_val = 0
    total_test = 0
    
    # Process each breed
    for breed in breed_folders:
        # Get all image files in this breed folder
        breed_images_path = os.path.join(images_dir, breed)
        image_files = [f for f in os.listdir(breed_images_path) 
                      if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))]
        
        if not image_files:
            print(f"Warning: No images found in {breed}")
            continue
        
        # Shuffle the images
        random.shuffle(image_files)
        
        # Calculate split sizes
        n_total = len(image_files)
        n_train = int(n_total * train_ratio)
        n_val = int(n_total * val_ratio)
        n_test = n_total - n_train - n_val
        
        # Split the images
        train_images = image_files[:n_train]
        val_images = image_files[n_train:n_train + n_val]
        test_images = image_files[n_train + n_val:]
        
        # Copy images and annotation to split directories
        for split_name, split_images in [
            ('train', train_images),
            ('val', val_images),
            ('test', test_images)
        ]:
            # Create breed subdirectory in images
            img_dest_dir = os.path.join(output_path, split_name, 'images', breed)
            os.makedirs(img_dest_dir, exist_ok=True)
            
            # Create breed subdirectory in annotation
            anno_dest_dir = os.path.join(output_path, split_name, 'annotation', breed)
            os.makedirs(anno_dest_dir, exist_ok=True)
            
            # Copy each image and its annotation
            for img_file in split_images:
                # Copy image
                src_img = os.path.join(breed_images_path, img_file)
                dst_img = os.path.join(img_dest_dir, img_file)
                shutil.copy2(src_img, dst_img)
                
                # Copy annotation (if exists)
                # Extract base name without extension
                base_name = os.path.splitext(img_file)[0]
                
                # Look for annotation with the same base name
                anno_src_path = os.path.join(annotation_dir, breed)
                if os.path.exists(anno_src_path):
                    # Try different annotation extensions
                    for ext in ['.xml', '.json', '.mat', '.txt', '']:
                        anno_file = f"{base_name}{ext}"
                        anno_path = os.path.join(anno_src_path, anno_file)
                        
                        if os.path.exists(anno_path):
                            dst_anno = os.path.join(anno_dest_dir, anno_file)
                            shutil.copy2(anno_path, dst_anno)
                            break
        
        # Update statistics
        total_train += len(train_images)
        total_val += len(val_images)
        total_test += len(test_images)
        
        print(f"{breed}: {len(train_images)} train, {len(val_images)} val, {len(test_images)} test")
    
    print("-" * 50)
    print(f"TOTAL: {total_train} train, {total_val} val, {total_test} test")
    print(f"Split complete! Organized dataset saved to: {output_path}")
    
    return output_path

# Run the split
organized_path = split_caltech_dogs_dataset(
    dataset_path='./dataset',  # Change this to your actual path
    output_path='./dogs_split'
)
# Out:
# Found 120 breed folders
# --------------------------------------------------
# n02085620-Chihuahua: 106 train, 22 val, 24 test
# n02085782-Japanese_spaniel: 129 train, 27 val, 29 test
# n02085936-Maltese_dog: 176 train, 37 val, 39 test
# n02086079-Pekinese: 104 train, 22 val, 23 test
# n02086240-Shih-Tzu: 149 train, 32 val, 33 test
# n02086646-Blenheim_spaniel: 131 train, 28 val, 29 test
# n02086910-papillon: 137 train, 29 val, 30 test
# n02087046-toy_terrier: 120 train, 25 val, 27 test
# n02087394-Rhodesian_ridgeback: 120 train, 25 val, 27 test
# n02088094-Afghan_hound: 167 train, 35 val, 37 test
# n02088238-basset: 122 train, 26 val, 27 test
# n02088364-beagle: 136 train, 29 val, 30 test
# n02088466-bloodhound: 130 train, 28 val, 29 test
# n02088632-bluetick: 119 train, 25 val, 27 test
# n02089078-black-and-tan_coonhound: 111 train, 23 val, 25 test
# n02089867-Walker_hound: 107 train, 22 val, 24 test
# n02089973-English_foxhound: 109 train, 23 val, 25 test
# n02090379-redbone: 103 train, 22 val, 23 test
# n02090622-borzoi: 105 train, 22 val, 24 test
# n02090721-Irish_wolfhound: 152 train, 32 val, 34 test
# n02091032-Italian_greyhound: 127 train, 27 val, 28 test
# n02091134-whippet: 130 train, 28 val, 29 test
# n02091244-Ibizan_hound: 131 train, 28 val, 29 test
# n02091467-Norwegian_elkhound: 137 train, 29 val, 30 test
# n02091635-otterhound: 105 train, 22 val, 24 test
# n02091831-Saluki: 140 train, 30 val, 30 test
# n02092002-Scottish_deerhound: 162 train, 34 val, 36 test
# n02092339-Weimaraner: 112 train, 24 val, 24 test
# n02093256-Staffordshire_bullterrier: 108 train, 23 val, 24 test
# n02093428-American_Staffordshire_terrier: 114 train, 24 val, 26 test
# n02093647-Bedlington_terrier: 127 train, 27 val, 28 test
# n02093754-Border_terrier: 120 train, 25 val, 27 test
# n02093859-Kerry_blue_terrier: 125 train, 26 val, 28 test
# n02093991-Irish_terrier: 118 train, 25 val, 26 test
# n02094114-Norfolk_terrier: 120 train, 25 val, 27 test
# n02094258-Norwich_terrier: 129 train, 27 val, 29 test
# n02094433-Yorkshire_terrier: 114 train, 24 val, 26 test
# n02095314-wire-haired_fox_terrier: 109 train, 23 val, 25 test
# n02095570-Lakeland_terrier: 137 train, 29 val, 31 test
# n02095889-Sealyham_terrier: 141 train, 30 val, 31 test
# n02096051-Airedale: 141 train, 30 val, 31 test
# n02096177-cairn: 137 train, 29 val, 31 test
# n02096294-Australian_terrier: 137 train, 29 val, 30 test
# n02096437-Dandie_Dinmont: 125 train, 27 val, 28 test
# n02096585-Boston_bull: 127 train, 27 val, 28 test
# n02097047-miniature_schnauzer: 107 train, 23 val, 24 test
# n02097130-giant_schnauzer: 109 train, 23 val, 25 test
# n02097209-standard_schnauzer: 108 train, 23 val, 24 test
# n02097298-Scotch_terrier: 110 train, 23 val, 25 test
# n02097474-Tibetan_terrier: 144 train, 30 val, 32 test
# n02097658-silky_terrier: 128 train, 27 val, 28 test
# n02098105-soft-coated_wheaten_terrier: 109 train, 23 val, 24 test
# n02098286-West_Highland_white_terrier: 118 train, 25 val, 26 test
# n02098413-Lhasa: 130 train, 27 val, 29 test
# n02099267-flat-coated_retriever: 106 train, 22 val, 24 test
# n02099429-curly-coated_retriever: 105 train, 22 val, 24 test
# n02099601-golden_retriever: 105 train, 22 val, 23 test
# n02099712-Labrador_retriever: 119 train, 25 val, 27 test
# n02099849-Chesapeake_Bay_retriever: 116 train, 25 val, 26 test
# n02100236-German_short-haired_pointer: 106 train, 22 val, 24 test
# n02100583-vizsla: 107 train, 23 val, 24 test
# n02100735-English_setter: 112 train, 24 val, 25 test
# n02100877-Irish_setter: 108 train, 23 val, 24 test
# n02101006-Gordon_setter: 107 train, 22 val, 24 test
# n02101388-Brittany_spaniel: 106 train, 22 val, 24 test
# n02101556-clumber: 105 train, 22 val, 23 test
# n02102040-English_springer: 111 train, 23 val, 25 test
# n02102177-Welsh_springer_spaniel: 105 train, 22 val, 23 test
# n02102318-cocker_spaniel: 111 train, 23 val, 25 test
# n02102480-Sussex_spaniel: 105 train, 22 val, 24 test
# n02102973-Irish_water_spaniel: 105 train, 22 val, 23 test
# n02104029-kuvasz: 105 train, 22 val, 23 test
# n02104365-schipperke: 107 train, 23 val, 24 test
# n02105056-groenendael: 105 train, 22 val, 23 test
# n02105162-malinois: 105 train, 22 val, 23 test
# n02105251-briard: 106 train, 22 val, 24 test
# n02105412-kelpie: 107 train, 22 val, 24 test
# n02105505-komondor: 107 train, 23 val, 24 test
# n02105641-Old_English_sheepdog: 118 train, 25 val, 26 test
# n02105855-Shetland_sheepdog: 109 train, 23 val, 25 test
# n02106030-collie: 107 train, 22 val, 24 test
# n02106166-Border_collie: 105 train, 22 val, 23 test
# n02106382-Bouvier_des_Flandres: 105 train, 22 val, 23 test
# n02106550-Rottweiler: 106 train, 22 val, 24 test
# n02106662-German_shepherd: 106 train, 22 val, 24 test
# n02107142-Doberman: 105 train, 22 val, 23 test
# n02107312-miniature_pinscher: 128 train, 27 val, 29 test
# n02107574-Greater_Swiss_Mountain_dog: 117 train, 25 val, 26 test
# n02107683-Bernese_mountain_dog: 152 train, 32 val, 34 test
# n02107908-Appenzeller: 105 train, 22 val, 24 test
# n02108000-EntleBucher: 141 train, 30 val, 31 test
# n02108089-boxer: 105 train, 22 val, 24 test
# n02108422-bull_mastiff: 109 train, 23 val, 24 test
# n02108551-Tibetan_mastiff: 106 train, 22 val, 24 test
# n02108915-French_bulldog: 111 train, 23 val, 25 test
# n02109047-Great_Dane: 109 train, 23 val, 24 test
# n02109525-Saint_Bernard: 118 train, 25 val, 27 test
# n02109961-Eskimo_dog: 105 train, 22 val, 23 test
# n02110063-malamute: 124 train, 26 val, 28 test
# n02110185-Siberian_husky: 134 train, 28 val, 30 test
# n02110627-affenpinscher: 105 train, 22 val, 23 test
# n02110806-basenji: 146 train, 31 val, 32 test
# n02110958-pug: 140 train, 30 val, 30 test
# n02111129-Leonberg: 147 train, 31 val, 32 test
# n02111277-Newfoundland: 136 train, 29 val, 30 test
# n02111500-Great_Pyrenees: 149 train, 31 val, 33 test
# n02111889-Samoyed: 152 train, 32 val, 34 test
# n02112018-Pomeranian: 153 train, 32 val, 34 test
# n02112137-chow: 137 train, 29 val, 30 test
# n02112350-keeshond: 110 train, 23 val, 25 test
# n02112706-Brabancon_griffon: 107 train, 22 val, 24 test
# n02113023-Pembroke: 126 train, 27 val, 28 test
# n02113186-Cardigan: 108 train, 23 val, 24 test
# n02113624-toy_poodle: 105 train, 22 val, 24 test
# n02113712-miniature_poodle: 108 train, 23 val, 24 test
# n02113799-standard_poodle: 111 train, 23 val, 25 test
# n02113978-Mexican_hairless: 108 train, 23 val, 24 test
# n02115641-dingo: 109 train, 23 val, 24 test
# n02115913-dhole: 105 train, 22 val, 23 test
# n02116738-African_hunting_dog: 118 train, 25 val, 26 test
# --------------------------------------------------
# TOTAL: 14355 train, 3025 val, 3200 test
# Split complete! Organized dataset saved to: ./dogs_split
